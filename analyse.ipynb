# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 2
#       1 import pandas as pd
# ----> 2 import matplotlib.pyplot as plt
#
# File c:\Users\iasamadov\Desktop\receipt_data\.venv\Lib\site-packages\matplotlib\pyplot.py:57
#      55 from cycler import cycler  # noqa: F401
#      56 import matplotlib
# ---> 57 import matplotlib.image
#      58 from matplotlib import _api
#      59 # Re-exported (import x as x) for typing.
#
# File c:\Users\iasamadov\Desktop\receipt_data\.venv\Lib\site-packages\matplotlib\image.py:23
#      20 # For user convenience, the names from _image are also imported into
#      21 # the image namespace
#      22 from matplotlib._image import *  # noqa: F401, F403
# ---> 23 import matplotlib.artist as martist
#      24 import matplotlib.colorizer as mcolorizer
#      25 from matplotlib.backend_bases import FigureCanvasBase
#
# ...

# %%
df = pd.read_csv('data/ai_improved.csv')

# %%
df
# Out:
#               filename                                      store_name  \
# 0    9FjTM9ngrpCu.jpeg           PROMART Məhdud Məsuliyyətli Cəmiyyəti
# 1    9FjTM9ngrpCu.jpeg           PROMART Məhdud Məsuliyyətli Cəmiyyəti
# 2    9FjTM9ngrpCu.jpeg           PROMART Məhdud Məsuliyyətli Cəmiyyəti
# 3    zbRTryY1MVkR.jpeg           PROMART Məhdud Məsuliyyətli Cəmiyyəti
# 4    zbRTryY1MVkR.jpeg           PROMART Məhdud Məsuliyyətli Cəmiyyəti
# ..                 ...                                             ...
# 207  HNZdbYNj18hu.jpeg  ARAZ SUPERMARKET MƏHDUD MƏSULİYYƏTLİ CƏMİYYƏTİ
# 208  HNZdbYNj18hu.jpeg  ARAZ SUPERMARKET MƏHDUD MƏSULİYYƏTLİ CƏMİYYƏTİ
# 209  HNZdbYNj18hu.jpeg  ARAZ SUPERMARKET MƏHDUD MƏSULİYYƏTLİ CƏMİYYƏTİ
# 210  HNZdbYNj18hu.jpeg  ARAZ SUPERMARKET MƏHDUD MƏSULİYYƏTLİ CƏMİYYƏTİ
# 211  HNZdbYNj18hu.jpeg  ARAZ SUPERMARKET MƏHDUD MƏSULİYYƏTLİ CƏMİYYƏTİ
#
#                                          store_address        store_code  \
# ...
